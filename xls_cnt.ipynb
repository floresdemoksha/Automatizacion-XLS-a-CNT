# %%
import pandas as pd

# %%
archivo = 'Junio 2025.xlsx'
hoja = '01 ALM BBVA MN'

# Cargar la hoja en un DataFrame
df = pd.read_excel(archivo, sheet_name=hoja)

# Columnas a eliminar
columnas_a_eliminar = [
    'SALDO', 'UUID', 'MÉTODO DE PAGO', 'UUID REP',
    'NO FACT', 'FECHA ENTREGA', 'ELECTRONICO',
    'OBSERVACIONES', 'NETO', 'IVA ACRED'
]

# Eliminar columnas si existen (por seguridad)
df = df.drop(columns=[col for col in columnas_a_eliminar if col in df.columns])
df
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...
# 365        NaN        NaN        NaN        NaN
# 366        NaN        NaN        NaN        NaN
# 367        NaN        NaN        NaN        NaN
# 368        NaN        NaN        NaN        NaN
# 369        NaN        NaN        NaN        NaN
#
#                                        Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0                                             NaN         NaN         NaN
# 1    Completo (entregado en físico y electrónico)         NaN         NaN
# 2                              Falta comprobación         NaN         NaN
# 3                       Falta pago y comprobación         NaN         NaN
# ...
